# %% [markdown]
# # Visualisation of performance

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
calr = pd.read_csv("../results/calr_metrics.csv")
calr.head()
# Out:
#    epoch      loss   accuracy
# 0      1  0.002452  10.937500
# 1      2  0.004892  17.187500
# 2      3  0.007316  18.229167
# 3      4  0.009733  17.578125
# 4      5  0.012152  15.625000

# %%
adam = pd.read_csv("../results/adam_metrics.csv")
adam.head()
# Out:
#    epoch      loss   accuracy
# 0      1  0.002449   6.250000
# 1      2  0.004847  12.500000
# 2      3  0.007051  18.750000
# 3      4  0.008845  26.953125
# 4      5  0.010477  29.687500

# %%
sgd = pd.read_csv("../results/sgd_metrics.csv")
sgd.head()
# Out:
#    epoch      loss   accuracy
# 0      1  0.002463   7.812500
# 1      2  0.004909  12.500000
# 2      3  0.007373  10.416667
# 3      4  0.009831  12.109375
# 4      5  0.012288  12.500000

# %% [markdown]
# ## Loss Variations

# %%
plt.figure()
plt.plot(calr["epoch"], calr["loss"], label="CALR")
plt.plot(adam["epoch"], adam["loss"], label="Adam")
plt.plot(sgd["epoch"], sgd["loss"], label="SGD")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Epoch")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Accuracy Variations

# %%
plt.figure()
plt.plot(calr["epoch"], calr["accuracy"], label="CALR")
plt.plot(adam["epoch"], adam["accuracy"], label="Adam")
plt.plot(sgd["epoch"], sgd["accuracy"], label="SGD")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Epoch")
plt.legend()
plt.grid()
plt.show()
