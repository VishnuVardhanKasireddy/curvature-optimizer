# %% [markdown]
# # Visualisation of performance

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
calr = pd.read_csv("../results/calr_metrics.csv")
calr.head()
# Out:
#    epoch      loss  accuracy
# 0      1  0.001994    35.472
# 1      2  0.002289    54.258
# 2      3  0.001170    62.484
# 3      4  0.001376    67.792
# 4      5  0.000628    71.976

# %%
adam = pd.read_csv("../results/adam_metrics.csv")
adam.head()
# Out:
#    epoch      loss  accuracy
# 0      1  0.001652    46.816
# 1      2  0.002227    60.594
# 2      3  0.001192    66.626
# 3      4  0.001092    70.332
# 4      5  0.000437    73.290

# %%
sgd = pd.read_csv("../results/sgd_metrics.csv")
sgd.head()
# Out:
#    epoch      loss  accuracy
# 0      1  0.001985    38.560
# 1      2  0.002671    56.966
# 2      3  0.001297    65.296
# 3      4  0.000933    69.566
# 4      5  0.000407    73.056

# %% [markdown]
# ## Loss Variations

# %%
plt.figure()
plt.plot(calr["epoch"], calr["loss"], label="CALR")
plt.plot(adam["epoch"], adam["loss"], label="Adam")
plt.plot(sgd["epoch"], sgd["loss"], label="SGD")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Epoch")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Accuracy Variations

# %%
plt.figure()
plt.plot(calr["epoch"], calr["accuracy"], label="CALR")
plt.plot(adam["epoch"], adam["accuracy"], label="Adam")
plt.plot(sgd["epoch"], sgd["accuracy"], label="SGD")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Epoch")
plt.legend()
plt.grid()
plt.show()
